# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import nbformat

# %%
# !pip install nbformat
# Out:
# ...
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached attrs-24.3.0-py3-none-any.whl (63 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# ...

# %%
import kaggle
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
api.model_list_cli()
# Out:
# ...
# Next Page Token = CfDJ8L3o_FPsMQlKvPRAcaVvXWNfQdfdks6oKlKC3fDuA0KnPXmXjAGDdLWHxVlQ8P0uM1WMherKyYiCjfikAKLgvjw
#     id  ref                                 title                 subtitle                                                                                                                                                                                                                     author
# ------  ----------------------------------  --------------------  ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -----------
# ...

# %% [markdown]
# # EDA

# %%
games = pd.read_csv('/Users/leox_50/.kaggle/players.csv')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1697 entries, 0 to 1696
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nflId        1697 non-null   int64
#  1   height       1697 non-null   object
#  2   weight       1697 non-null   int64
#  3   birthDate    1210 non-null   object
#  4   collegeName  1697 non-null   object
#  5   position     1697 non-null   object
#  6   displayName  1697 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 92.9+ KB

# %%
tracking_week_1 = pd.read_csv('/Users/leox_50/.kaggle/tracking_week_1.csv')

# %%
tracking_week_1[(
    tracking_week_1['gameId'] == 2022091200) &
    (tracking_week_1['nflId'] == 35459.0)]
# Out:
#             gameId  playId    nflId     displayName  frameId    frameType  \
# 0       2022091200      64  35459.0  Kareem Jackson        1  BEFORE_SNAP
# 1       2022091200      64  35459.0  Kareem Jackson        2  BEFORE_SNAP
# 2       2022091200      64  35459.0  Kareem Jackson        3  BEFORE_SNAP
# 3       2022091200      64  35459.0  Kareem Jackson        4  BEFORE_SNAP
# 4       2022091200      64  35459.0  Kareem Jackson        5  BEFORE_SNAP
# ...            ...     ...      ...             ...      ...          ...
# 434574  2022091200    4012  35459.0  Kareem Jackson       59   AFTER_SNAP
# 434575  2022091200    4012  35459.0  Kareem Jackson       60   AFTER_SNAP
# 434576  2022091200    4012  35459.0  Kareem Jackson       61   AFTER_SNAP
# 434577  2022091200    4012  35459.0  Kareem Jackson       62   AFTER_SNAP
# 434578  2022091200    4012  35459.0  Kareem Jackson       63   AFTER_SNAP
#
#                          time  jerseyNumber club playDirection      x      y  \
# ...

# %%
tracking_week_1.shape[0]
# Out:
# 7104700

# %%
def display_movement(player_id: str, gameId: int):
    
    df = tracking_week_1[(
        tracking_week_1['nflId'] == player_id) &
        (tracking_week_1['playId'] == gameId)]
    
    df.
    x = t + t ** 2
    y = t - t ** 2
    xm = np.min(x) - 1.5
    xM = np.max(x) + 1.5
    ym = np.min(y) - 1.5
    yM = np.max(y) + 1.5
    N = 25
    s = np.linspace(-1, 1, N)
    xx = s + s ** 2
    yy = s - s ** 2

    fig = go.Figure(
    data=[go.Scatter(x=x, y=y,
                        mode="lines",
                        line=dict(width=2, color="blue")),
            go.Scatter(x=[xx[0]], y=[yy[0]],
                        mode="markers",
                        marker=dict(color="red", size=10))])
    fig.update_layout(width=600, height=450,
            xaxis=dict(range=[xm, xM], autorange=False, zeroline=False),
            yaxis=dict(range=[ym, yM], autorange=False, zeroline=False),
            title_text="Kinematic Generation of a Planar Curve", title_x=0.5,
            updatemenus = [dict(type = "buttons",
            buttons = [
                dict(
                    args = [None, {"frame": {"duration": 10, "redraw": False},
                                    "fromcurrent": True, "transition": {"duration": 10}}],
                    label = "Play",
                    method = "animate",

                    )])])

    fig.update(frames=[go.Frame(
                            data=[go.Scatter(
                                    x=[xx[k]],
                                    y=[yy[k]])],
                            traces=[1]) # fig.data[1] is updated by each frame
            for k in range(N)])

    fig.show()

# %%
display_movement(player_name: str, playId: int):

# %%
tracking_week_1.gameId.nunique()
# Out:
# 16

# %%
tracking_week_1.head(10)
# Out:
#        gameId  playId    nflId     displayName  frameId    frameType  \
# 0  2022091200      64  35459.0  Kareem Jackson        1  BEFORE_SNAP
# 1  2022091200      64  35459.0  Kareem Jackson        2  BEFORE_SNAP
# 2  2022091200      64  35459.0  Kareem Jackson        3  BEFORE_SNAP
# 3  2022091200      64  35459.0  Kareem Jackson        4  BEFORE_SNAP
# 4  2022091200      64  35459.0  Kareem Jackson        5  BEFORE_SNAP
# 5  2022091200      64  35459.0  Kareem Jackson        6  BEFORE_SNAP
# 6  2022091200      64  35459.0  Kareem Jackson        7  BEFORE_SNAP
# 7  2022091200      64  35459.0  Kareem Jackson        8  BEFORE_SNAP
# 8  2022091200      64  35459.0  Kareem Jackson        9  BEFORE_SNAP
# 9  2022091200      64  35459.0  Kareem Jackson       10  BEFORE_SNAP
#
#                     time  jerseyNumber club playDirection      x      y     s  \
# 0  2022-09-13 00:16:03.5          22.0  DEN         right  51.06  28.55  0.72
# ...

# %%
tracking_week_1['event'].unique()
# Out:
# array(['huddle_break_offense', nan, 'line_set', 'man_in_motion',
#        'ball_snap', 'handoff', 'first_contact', 'tackle', 'pass_forward',
#        'pass_arrived', 'pass_outcome_caught', 'touchdown', 'dropped_pass',
#        'pass_outcome_incomplete', 'play_action', 'out_of_bounds', 'run',
#        'qb_sack', 'pass_tipped', 'fumble', 'fumble_offense_recovered',
#        'shift', 'fumble_defense_recovered', 'touchback', 'qb_strip_sack',
#        'qb_kneel', 'timeout_away', 'snap_direct',
#        'pass_outcome_interception', 'qb_slide', 'play_submit',
#        'pass_outcome_touchdown', 'lateral', 'qb_spike', 'pass_shovel',
#        'run_pass_option', 'huddle_start_offense'], dtype=object)

# %%
# games.csv

There are 136 entries
The data is for season's year 2022 only, about 2 years old
The data is clean in terms of no missing values
Only week 1 through 5 have 16 games, rest of the weeks have less than 16 games
The distribution of home and visitor scores is distrubted evenly
The games are played between 2022-09-08 and 2022-11-07
There are 32 teams, all teams in NFL played at least once as home team, with NO having played 6 games, and PIT played 3 games
There are 32 teams, all teams in NFL played at least once as visitor team, with BUF having played 5 games, and DAL played 3 games
For the homeFinalScore, number of outliers is 2; for visitorFinalScore number of outliers is 1
The correlation between homeFinalScore and visitorFinalScore is 0.15 which indicates a very weak positive correlation, suggesting the scores of home and visitor games are only slightly related

# %% [markdown]
# # possible outcomes:
#
# ## Metrics development:
# ### Option 1 - Team level metric:
# #### Main question to reply: what metric should target the team to increase the probability of winning?
# #### based on the data find out patterns and suggest relationship model
# #### explain why it is important. create metrics tree based on the captured relationships
# #### Maybe xg boost for causal inference: https://arxiv.org/html/2404.00751v1
# #### outcome in the form: Team with a metric A with value B has a +C probabilty of winning the game (may vary on the time of champoinship targeting Would NFL teams (or the league office) be able to use these results on a week-to-week basis?)
#
# ### Option 2 - Player level metric:
# #### Main question: What should an individual player do to increase the probability of scoring/defending?
#
# ### Analytical Software development:
# #### Maybe using streamlit suggest an interactive dashboard to monitor games
#
# ## Game setup improvement:
# ### Option 1 - Coach level question
# ### Main question: what should coach do during the game to increase the probability to win?
# ### how should the players move?
# ### how should the coach react to the opposite team choice? To the substitutions? To scheme for the game?

# %%
# possible outcomes

#metrics development
